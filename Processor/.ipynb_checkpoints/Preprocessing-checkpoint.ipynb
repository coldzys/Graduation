# %%
from pyspark.sql import SparkSession
from pyspark import pandas as pd
from datetime import datetime

# %%
df = pd.read_json("datasets/timviec365.json")

# %%
df[[
    "Tên công ty", 
    "Tỉnh thành tuyển dụng", 
    "Tên công việc", 
    "Ngày cập nhật", 
    "Ngành nghề", 
    "Lương", 
    "Kinh nghiệm", 
    "Yêu cầu bằng cấp", 
    "Yêu cầu giới tính"
]]
# Out:
#                                             Tên công ty Tỉnh thành tuyển dụng  \
# 0     CÔNG TY TNHH BẢO HIỂM NHÂN THỌ DAIICHI LIFE CH...                Hà Nội
# 1                                      Công Ty Tnhh Wla                Hà Nội
# 2                                      Công Ty Tnhh Wla                Hà Nội
# 3                          Công ty TNHH TMDV Diên Khánh               Cần Thơ
# 4                          Công ty TNHH TMDV Diên Khánh                Cà Mau
# ...                                                 ...                   ...
# 5107      công ty bảo hiểm nhân thọ chubb life việt nam             Hải Dương
# 5108              Công ty TNHH VietPhil Education Group                Hà Nội
# 5109  CÔNG TY BHNT DAI ICHI VIỆT NAM CHI NHÁNH HÀ NỘI__                Hà Nội
# 5110                                           Mai Pham           Hồ Chí Minh
# 5111                                           Mai Pham           Hồ Chí Minh
#
# ...
